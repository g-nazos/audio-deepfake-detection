# %% [markdown]
# ## ITW Exploration - Normalization

# %%
import os
import subprocess
import re
import pandas as pd

from configs.config import ITW_DATASET_PATH, DATASET_PATH, ELEVEN_LABS_DATASET_PATH

SOX = "sox"
FFMPEG = "ffmpeg"

# %%
AUDIO_DIR = os.path.join(ITW_DATASET_PATH, "fake")
rows = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    lufs = float(lufs_re.search(ff_out).group(1))

    rows.append((f, sr, ch, lufs))

df = pd.DataFrame(rows, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")
# Out:
# DONE
#           file  sample_rate  channels  lufs
# 0  file001.wav        16000         1 -35.9
# 1  file002.wav        16000         1 -35.1
# 2  file003.wav        16000         1 -34.6
# 3  file004.wav        16000         1 -35.1
# 4  file005.wav        16000         1 -32.1

# %%
AUDIO_DIR = os.path.join(ITW_DATASET_PATH, "real")
rows_real = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    match = lufs_re.search(ff_out)
    if match:
        lufs = float(match.group(1))
    else:
        print(f"Warning: LUFS not found for {path}")
        lufs = None  # or skip the file entirely

    rows_real.append((f, sr, ch, lufs))

df_real = pd.DataFrame(rows_real, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")
# Out:
# Warning: LUFS not found for c:\Users\konst\Documents\in_the_wild_dataset\real\15113.wav
# DONE

# %%
df_fake = pd.DataFrame(rows, columns=["file", "sample_rate", "channels", "lufs"])
df_fake.to_csv(r"c:\Users\konst\Desktop\itw_fake_sr_chan_lufs")
df_real = pd.DataFrame(rows_real, columns=["file", "sample_rate", "channels", "lufs"])
df_real.to_csv(r"c:\Users\konst\Desktop\itw_real_sr_chan_lufs")
print(df_real.head())
# Out:
#         file  sample_rate  channels  lufs
# 0    100.wav        16000         1 -22.1
# 1   1000.wav        16000         1 -29.6
# 2  10001.wav        16000         1 -23.6
# 3  10003.wav        16000         1 -29.1
# 4  10004.wav        16000         1 -26.2

# %%
AUDIO_DIR = os.path.join(DATASET_PATH, "training", "real")
rows_real_train = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    match = lufs_re.search(ff_out)
    if match:
        lufs = float(match.group(1))
    else:
        print(f"Warning: LUFS not found for {path}")
        lufs = None  # or skip the file entirely

    rows_real_train.append((f, sr, ch, lufs))

df_real_train = pd.DataFrame(rows_real_train, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")

df_real_train = pd.DataFrame(rows_real_train, columns=["file", "sample_rate", "channels", "lufs"])
df_real_train.to_csv(r"c:\Users\konst\Desktop\FoR_real_train_sr_chan_lufs")
# Out:
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file11064.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file14041.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file15440.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file15932.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file22565.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file23005.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file23570.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file26291.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file29649.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file32532.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\real\file4095.wav_16k.wav_norm.wav_mono.wav_silence.wav
# DONE

# %%
AUDIO_DIR = os.path.join(DATASET_PATH, "training", "fake")
rows_fake_train = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    match = lufs_re.search(ff_out)
    if match:
        lufs = float(match.group(1))
    else:
        print(f"Warning: LUFS not found for {path}")
        lufs = None  # or skip the file entirely

    rows_fake_train.append((f, sr, ch, lufs))

df_fake_train = pd.DataFrame(rows_fake_train, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")

df_fake_train = pd.DataFrame(rows_fake_train, columns=["file", "sample_rate", "channels", "lufs"])
df_fake_train.to_csv(r"c:\Users\konst\Desktop\FoR_fake_train_sr_chan_lufs")
# Out:
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file10063.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file10542.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file11019.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file11744.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file12189.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file12820.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file14370.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file15383.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file16617.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file20955.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file21630.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file21786.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file21936.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25009.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25125.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25184.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25205.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25806.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file25929.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file27130.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file27739.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file2846.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file2945.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file31289.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file32428.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file32692.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file33902.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file5737.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file7698.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file7704.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file9272.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# Warning: LUFS not found for c:\Users\konst\Documents\FoR_dataset\for-norm\for-norm\training\fake\file9938.mp3.wav_16k.wav_norm.wav_mono.wav_silence.wav
# DONE

# %%
# Mean of LUFS
mean_lufs = df_fake['lufs'].mean()

# Standard deviation of LUFS
std_lufs = df_fake['lufs'].std()
print("For fake files of ITW")
print(f"Mean LUFS: {mean_lufs:.2f}")
print(f"LUFS Standard Deviation : {std_lufs:.2f}")
# Out:
# For fake files of ITW
# Mean LUFS: -28.58
# LUFS Standard Deviation : 4.18

# %%
# Mean of LUFS
mean_lufs = df_real['lufs'].mean()

# Standard deviation of LUFS
std_lufs = df_real['lufs'].std()
print("For real files of ITW")
print(f"Mean LUFS: {mean_lufs:.2f}")
print(f"LUFS Standard Deviation: {std_lufs:.2f}")
# Out:
# For real files of ITW
# Mean LUFS: -25.73
# LUFS Standard Deviation: 5.84

# %%
# Mean of LUFS
mean_lufs = df_fake_train['lufs'].mean()

# Standard deviation of LUFS
std_lufs = df_fake_train['lufs'].std()
print("For fake files of FoR")
print(f"Mean LUFS: {mean_lufs:.2f}")
print(f"LUFS Standard Deviation: {std_lufs:.2f}")
# Out:
# For fake files of FoR
# Mean LUFS: -15.55
# LUFS Standard Deviation: 2.04

# %%
# Mean of LUFS
mean_lufs = df_real_train['lufs'].mean()

# Standard deviation of LUFS
std_lufs = df_real_train['lufs'].std()
print("For real files of FoR")

print(f"Mean LUFS: {mean_lufs:.2f}")
print(f"LUFS Standard Deviation: {std_lufs:.2f}")
# Out:
# For real files of FoR
# Mean LUFS: -17.89
# LUFS Standard Deviation: 2.50

# %%
# Get all unique values in 'channels'
unique_channels = df['channels'].unique()
print(unique_channels)
# Out:
# [1]

# %%
AUDIO_DIR = os.path.join(ITW_DATASET_PATH, "fake_norm")
rows_fake_after_loud_norm = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    match = lufs_re.search(ff_out)
    if match:
        lufs = float(match.group(1))
    else:
        print(f"Warning: LUFS not found for {path}")
        lufs = None  # or skip the file entirely

    rows_fake_after_loud_norm.append((f, sr, ch, lufs))

df_fake_after_loud_norm = pd.DataFrame(rows_fake_after_loud_norm, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")

df_fake_after_loud_norm = pd.DataFrame(rows_fake_after_loud_norm, columns=["file", "sample_rate", "channels", "lufs"])
df_fake_after_loud_norm.to_csv(r"c:\Users\konst\Desktop\FoR_fake_after_loud_norm_sr_chan_lufs")

# Mean of LUFS
mean_lufs = df_fake_after_loud_norm['lufs'].mean()

# Standard deviation of LUFS
std_lufs = df_fake_after_loud_norm['lufs'].std()
print("For real files of FoR")

print(f"Mean LUFS: {mean_lufs:.2f}")
print(f"LUFS Standard Deviation: {std_lufs:.2f}")
# Out:
# DONE
# For real files of FoR
# Mean LUFS: -18.19
# LUFS Standard Deviation: 1.33

# %% [markdown]
# ### Eleven labs audio files preprocessing

# %%
AUDIO_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "fake")
rows = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    lufs = float(lufs_re.search(ff_out).group(1))

    rows.append((f, sr, ch, lufs))

df_fake = pd.DataFrame(rows, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")
print(df.head())
# Out:
# DONE
#           file  sample_rate  channels  lufs
# 0  file001.wav        16000         1 -35.9
# 1  file002.wav        16000         1 -35.1
# 2  file003.wav        16000         1 -34.6
# 3  file004.wav        16000         1 -35.1
# 4  file005.wav        16000         1 -32.1

# %%
INPUT_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "fake")
OUTPUT_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "fake_normalized")
TARGET_LUFS = -15.0  # Common broadcast standard

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

for f in os.listdir(INPUT_DIR):
    if not f.endswith(".wav"):
        continue

    input_path = os.path.join(INPUT_DIR, f)
    output_path = os.path.join(OUTPUT_DIR, f)

    print(f"Normalizing: {f} to {TARGET_LUFS} LUFS...")

    # Using the 'loudnorm' filter in a single pass (simple mode)
    # This automatically adjusts integrated loudness, range, and true peak.
    cmd = [
        FFMPEG, "-y", "-i", input_path,
        "-filter:a", f"loudnorm=I={TARGET_LUFS}:LRA=11:TP=-1.5",
        output_path
    ]

    try:
        subprocess.run(cmd, check=True, stderr=subprocess.PIPE)
    except subprocess.CalledProcessError as e:
        print(f"Error processing {f}: {e}")

print(f"\nDONE! Files saved to: {OUTPUT_DIR}")
# Out:
# Normalizing: file001.wav to -15.0 LUFS...
# Normalizing: file002.wav to -15.0 LUFS...
# Normalizing: file003.wav to -15.0 LUFS...
# Normalizing: file004.wav to -15.0 LUFS...
# Normalizing: file005.wav to -15.0 LUFS...
# Normalizing: file006.wav to -15.0 LUFS...
# Normalizing: file007.wav to -15.0 LUFS...
# Normalizing: file008.wav to -15.0 LUFS...
# Normalizing: file009.wav to -15.0 LUFS...
# Normalizing: file010.wav to -15.0 LUFS...
# Normalizing: file011.wav to -15.0 LUFS...
# Normalizing: file012.wav to -15.0 LUFS...
# Normalizing: file013.wav to -15.0 LUFS...
# Normalizing: file014.wav to -15.0 LUFS...
# Normalizing: file015.wav to -15.0 LUFS...
# Normalizing: file016.wav to -15.0 LUFS...
# Normalizing: file017.wav to -15.0 LUFS...
# Normalizing: file018.wav to -15.0 LUFS...
# Normalizing: file019.wav to -15.0 LUFS...
# Normalizing: file020.wav to -15.0 LUFS...
# Normalizing: file021.wav to -15.0 LUFS...
# Normalizing: file022.wav to -15.0 LUFS...
# Normalizing: file023.wav to -15.0 LUFS...
# Normalizing: file024.wav to -15.0 LUFS...
# Normalizing: file025.wav to -15.0 LUFS...
# Normalizing: file026.wav to -15.0 LUFS...
# Normalizing: file027.wav to -15.0 LUFS...
# Normalizing: file028.wav to -15.0 LUFS...
# Normalizing: file029.wav to -15.0 LUFS...
# Normalizing: file030.wav to -15.0 LUFS...
# Normalizing: file031.wav to -15.0 LUFS...
# Normalizing: file032.wav to -15.0 LUFS...
# Normalizing: file033.wav to -15.0 LUFS...
# Normalizing: file034.wav to -15.0 LUFS...
# Normalizing: file035.wav to -15.0 LUFS...
# Normalizing: file036.wav to -15.0 LUFS...
# Normalizing: file037.wav to -15.0 LUFS...
# Normalizing: file038.wav to -15.0 LUFS...
# Normalizing: file039.wav to -15.0 LUFS...
# Normalizing: file040.wav to -15.0 LUFS...
# Normalizing: file041.wav to -15.0 LUFS...
# Normalizing: file042.wav to -15.0 LUFS...
# Normalizing: file043.wav to -15.0 LUFS...
# Normalizing: file044.wav to -15.0 LUFS...
# Normalizing: file045.wav to -15.0 LUFS...
# Normalizing: file046.wav to -15.0 LUFS...
# Normalizing: file047.wav to -15.0 LUFS...
# Normalizing: file048.wav to -15.0 LUFS...
# Normalizing: file049.wav to -15.0 LUFS...
# Normalizing: file050.wav to -15.0 LUFS...
# Normalizing: file051.wav to -15.0 LUFS...
# Normalizing: file052.wav to -15.0 LUFS...
# Normalizing: file053.wav to -15.0 LUFS...
# Normalizing: file054.wav to -15.0 LUFS...
# Normalizing: file055.wav to -15.0 LUFS...
# Normalizing: file056.wav to -15.0 LUFS...
# Normalizing: file057.wav to -15.0 LUFS...
# Normalizing: file058.wav to -15.0 LUFS...
# Normalizing: file059.wav to -15.0 LUFS...
# Normalizing: file060.wav to -15.0 LUFS...
# Normalizing: file061.wav to -15.0 LUFS...
# Normalizing: file062.wav to -15.0 LUFS...
#
# DONE! Files saved to: C:\Users\konst\Documents\GitHub\audio-deepfake-detection\elevenlabs-dataset\fake_normalized

# %%
AUDIO_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "fake_normalized")
rows = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    lufs = float(lufs_re.search(ff_out).group(1))

    rows.append((f, sr, ch, lufs))

df = pd.DataFrame(rows, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")
print(df.head())
# Out:
# DONE
#           file  sample_rate  channels  lufs
# 0  file001.wav       192000         1 -16.3
# 1  file002.wav       192000         1 -15.8
# 2  file003.wav       192000         1 -15.4
# 3  file004.wav       192000         1 -16.4
# 4  file005.wav       192000         1 -15.3

# %%
# --- CONFIGURATION ---
INPUT_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "real")
OUTPUT_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "real_normalized")
TARGET_LUFS = -18.0  # Common broadcast standard

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

for f in os.listdir(INPUT_DIR):
    if not f.endswith(".wav"):
        continue

    input_path = os.path.join(INPUT_DIR, f)
    output_path = os.path.join(OUTPUT_DIR, f)

    print(f"Normalizing: {f} to {TARGET_LUFS} LUFS...")

    # Using the 'loudnorm' filter in a single pass (simple mode)
    # This automatically adjusts integrated loudness, range, and true peak.
    cmd = [
        FFMPEG, "-y", "-i", input_path,
        "-filter:a", f"loudnorm=I={TARGET_LUFS}:LRA=11:TP=-1.5",
        output_path
    ]

    try:
        subprocess.run(cmd, check=True, stderr=subprocess.PIPE)
    except subprocess.CalledProcessError as e:
        print(f"Error processing {f}: {e}")

print(f"\nDONE! Files saved to: {OUTPUT_DIR}")
# Out:
# Normalizing: george_downsampled_single_channel_chunk_0000.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0001.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0002.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0003.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0004.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0005.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0006.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0007.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0008.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0009.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0010.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0011.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0012.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0013.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0014.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0015.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0016.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0017.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0018.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0019.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0020.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0021.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0022.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0023.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0024.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0025.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0026.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0027.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0028.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0029.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0030.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0031.wav to -18.0 LUFS...
# Normalizing: george_downsampled_single_channel_chunk_0032.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0000.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0001.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0002.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0003.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0004.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0005.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0006.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0007.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0008.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0009.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0010.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0011.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0012.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0013.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0014.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0015.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0016.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0017.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0018.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0019.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0020.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0021.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0022.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0023.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0024.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0025.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0026.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0027.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0028.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0029.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0030.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0031.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0032.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0033.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0034.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0035.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0036.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0037.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0038.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0039.wav to -18.0 LUFS...
# Normalizing: kostas_audio_chunk_0040.wav to -18.0 LUFS...
#
# DONE! Files saved to: C:\Users\konst\Documents\GitHub\audio-deepfake-detection\elevenlabs-dataset\real_normalized

# %%
AUDIO_DIR = os.path.join(ELEVEN_LABS_DATASET_PATH, "real_normalized")
rows = []
lufs_re = re.compile(r"Input Integrated:\s*(-?\d+(\.\d+)?)")


for f in os.listdir(AUDIO_DIR):
    if not f.endswith(".wav"):
        continue

    path = os.path.join(AUDIO_DIR, f)

    # soxi (metadata)
    soxi_out = subprocess.check_output([SOX, "--info", path], text=True)

    sr = int(re.search(r"Sample Rate\s*:\s*(\d+)", soxi_out).group(1))
    ch = int(re.search(r"Channels\s*:\s*(\d+)", soxi_out).group(1))

    # ffmpeg loudness analysis
    ff_out = subprocess.check_output(
        [
            FFMPEG, "-i", path,
            "-filter:a", "loudnorm=print_format=summary",
            "-f", "null", "-"
        ],
        stderr=subprocess.STDOUT,
        text=True
    )
    lufs = float(lufs_re.search(ff_out).group(1))

    rows.append((f, sr, ch, lufs))

df = pd.DataFrame(rows, columns=["file", "sample_rate", "channels", "lufs"])

print("DONE")
print(df.head())
# Out:
# DONE
#                                                file  sample_rate  channels  \
# 0  george_downsampled_single_channel_chunk_0000.wav       192000         1
# 1  george_downsampled_single_channel_chunk_0001.wav       192000         1
# 2  george_downsampled_single_channel_chunk_0002.wav       192000         1
# 3  george_downsampled_single_channel_chunk_0003.wav       192000         1
# 4  george_downsampled_single_channel_chunk_0004.wav       192000         1
#
#    lufs
# 0 -17.9
# 1 -17.7
# 2 -18.1
# 3 -18.6
# 4 -19.0
